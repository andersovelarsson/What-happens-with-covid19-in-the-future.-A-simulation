# %%
import SirModel as sirm
sirdm1 = sirm.SirModel(k12=0.3077, k13=0.000506*2.5, So = 10E6, dateStart = '2020-02-24', plotDateRange = ['2020-03-01','2022-01-01'])
sirdm1.Ro =    {'2020-01-01': 2.23826201,
                '2020-03-16': 1.61895397, 
                '2020-04-02': 1.04304145, 
                '2020-04-24': 1.0269131, 
                '2020-05-23': 1.06244306,
                '2020-07-01': 0.89177499,  
                '2020-07-20': 1.07284479,
                '2020-08-20': 1.1400000} 
sirdm1.plot()

# %%
import SirModel as sirm
sirdm2 = sirm.SirModel(k12=0.3077, k13=0.000506*2.5, So = 10E6, dateStart = '2020-02-24', plotDateRange = ['2020-03-01','2022-01-01'])
sirdm2.Ro ={'2020-01-01': 2.23826201,
            '2020-03-16': 1.61895397, 
            '2020-04-02': 1.04304145, 
            '2020-04-24': 1.0269131, 
            '2020-05-23': 1.06244306,
            '2020-07-01': 0.89177499,  
            '2020-07-20': 1.07284479,
            '2020-08-20': 1.1400000,
            '2020-10-20': 1.2} 
sirdm2.plot()
