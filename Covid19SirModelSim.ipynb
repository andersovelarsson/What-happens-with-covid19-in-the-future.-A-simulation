# %%
import SirModel as sirm
sirdm1 = sirm.SirModel(k12=0.3077, k13=0.000506*2.5, So = 10E6, dateStart = '2020-02-24', plotDateRange = ['2020-03-01','2022-01-01'])
sirdm1.Ro =    {'2020-01-01': 2.23835106,
                '2020-03-16': 1.61784849, 
                '2020-04-02': 1.0445707, 
                '2020-04-24': 1.02400432, 
                '2020-05-23': 1.07028485,
                '2020-06-20': 0.97462033,  
                '2020-08-01': 1.02010642,
                '2020-08-20': 1.21356282,
                '2020-10-16': 1.58,
                '2020-11-06': 1.37,
                '2020-11-20': 1.323 }  
sirdm1.plot()
# Out:
# Update the file:Doc/covid-19_sim.png
